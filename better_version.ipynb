# %%
with open("91gev.dat") as file:
    n_parts = []
    for line in file:
        if line.startswith("#"):
            continue
        elif len(line.strip()) == 1:
            n_parts.append(int(line.strip()[0]))

# %%
n_parts
# Out:
# [5,
#  6,
#  3,
#  4,
#  1,
#  2,
#  4,
#  5,
#  4,
#  2,
#  5,
#  5,
#  4,
#  7,
#  3,
#  5,
#  5,
#  4,
#  3,
#  5,
#  2,
#  3,
#  3,
#  3,
#  1,
#  6,
#  3,
#  2,
#  3,
#  1,
#  3,
#  2,
#  5,
#  4,
#  4,
#  3,
#  5,
#  2,
#  1,
#  2,
#  2,
#  2,
#  7,
#  2,
#  7,
#  5,
#  4,
#  4,
#  8,
#  3,
#  3,
#  3,
#  3,
#  2,
#  6,
#  9,
#  2,
#  6,
#  7,
#  2,
#  2,
#  4,
#  5,
#  4,
#  6,
#  4,
#  1,
#  3,
#  7,
#  2,
#  6,
#  3,
#  6,
#  2,
#  1,
#  5,
#  4,
#  4,
#  5,
#  1,
#  2,
#  3,
#  2,
#  2,
#  3,
#  2,
#  4,
#  1,
#  5,
#  6,
#  4,
#  2,
#  2,
#  2,
#  1,
#  3,
#  3,
#  5,
#  2,
#  1,
#  4,
#  1,
#  2,
#  8,
#  2,
#  3,
#  1,
#  1,
#  1,
#  3,
#  2,
#  3,
#  2,
#  4,
#  2,
#  3,
#  4,
#  4,
#  2,
#  1,
#  4,
#  8,
#  6,
#  5,
#  3,
#  1,
#  8,
#  1,
#  5,
#  6,
#  6,
#  3,
#  4,
#  2,
#  5,
#  6,
#  2,
#  1,
#  4,
#  3,
#  5,
#  3,
#  5,
#  1,
#  6,
#  2,
#  4,
#  2,
#  4,
#  3,
#  2,
#  2,
#  2,
#  9,
#  6,
#  5,
#  8,
#  4,
#  5,
#  1,
#  3,
#  4,
#  1,
#  8,
#  5,
#  2,
# ...
